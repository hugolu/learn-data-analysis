# %%
import numpy as np
import pandas as pd

# %%
# install xlrd first
df = pd.read_excel('test_data.xls')

# %%
df[:5]
# Out:
#   ship_name  ship_mobile         order_id  total_amount  final_amount  \
# 0       姐客戶  16143836292  170102235550041          34.0          34.0
# 1       五客戶  16594905358  170101065127820         128.0         128.0
# 2       五客戶  16594905358  170101065736249         115.2         115.2
# 3       五客戶  16594905358  170102211599793          84.0          84.0
# 4       五客戶  16594905358  170104110758077         239.5         239.5
#
#    pay_status  ship_status is_delivery try_order  erp_order_id  \
# 0           1            1           Y     False             1
# 1           1            1           Y     False             1
# 2           1            1           Y     False             1
# 3           1            1           Y     False             1
# 4           0            0           Y     False             1
#
#           ...          fuzzy   longitude   latitude scalping  \
# 0         ...              0  121.523968  31.234887    False
# ...
